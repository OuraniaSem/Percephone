# %% [markdown]
# # Response characterization
# **9th april 2024 (edited the 6th May 2024)**
#
# *Célien Vandromme*
#
# ---

# %%
import numpy as np
import pandas as pd
import percephone.core.recording as pc
import os
import matplotlib
import percephone.plts.stats as ppt
import matplotlib.pyplot as plt
from multiprocessing import Pool, cpu_count, pool
import warnings

plt.switch_backend("Qt5Agg")
matplotlib.use("Qt5Agg")
# %matplotlib inline
warnings.filterwarnings('ignore')

save_figure = True
# %matplotlib inline

# %%
user = "Célien"

if user == "Célien":
    directory = "C:/Users/cvandromme/Desktop/Data/"
    roi_path = "C:/Users/cvandromme/Desktop/FmKO_ROIs&inhibitory.xlsx"
    server_address = "Z:/Current_members/Ourania_Semelidou/2p/Figures_paper & submissions/Figures_202503/"
elif user == "Théo":
    directory = "/datas/Théo/Projects/Percephone/data/Amplitude_Detection/loop_format_tau_02/"
    roi_path = directory + "/FmKO_ROIs&inhibitory.xlsx"
    server_address = "/run/user/1004/gvfs/smb-share:server=engram.local,share=data/Current_members/Ourania_Semelidou/2p/Figures_paper/"
    
roi_info = pd.read_excel(roi_path)
files = os.listdir(directory)
files_ = [file for file in files if file.endswith("synchro")]

def opening_rec(fil, i):
    rec = pc.RecordingAmplDet(directory + fil + "/", 0, roi_path)
    return rec

workers = cpu_count()
if user == "Célien":
    pool = pool.ThreadPool(processes=workers)
elif user == "Théo":
    pool = Pool(processes=workers)
async_results = [pool.apply_async(opening_rec, args=(file, i)) for i, file in enumerate(files_)]
recs = {ar.get().filename: ar.get() for ar in async_results}
# Out:
# 5886: Behavioural information already incorporated in the analog.
# 4754: Behavioural information already incorporated in the analog.
# 5889: Behavioural information already incorporated in the analog.
# 5890: Behavioural information already incorporated in the analog.
# 5893: Behavioural information already incorporated in the analog.
# 5879: Behavioural information already incorporated in the analog.
# 5896: Behavioural information already incorporated in the analog.
# 4745: Behavioural information already incorporated in the analog.
# 4445: Behavioural information already incorporated in the analog.
# 4939: Behavioural information already incorporated in the analog.
# 4456: Behavioural information already incorporated in the analog.
# 4756: Behavioural information already incorporated in the analog.
# 6606: Behavioural information already incorporated in the analog.
# 5873: Behavioural information already incorporated in the analog.
# 6609: Behavioural information already incorporated in the analog.
# 5881: Behavioural information already incorporated in the analog.
# 7539: Behavioural information already incorporated in the analog.
# 6601: Behavioural information already incorporated in the analog.
# 6611: Behavioural information already incorporated in the analog.
# 7527: Behavioural information already incorporated in the analog.7554: Behavioural information already incorporated in the analog.
#
# 7529: Behavioural information already incorporated in the analog.
# 7540: Behavioural information already incorporated in the analog.
# 7559: Behavioural information already incorporated in the analog.
# 7552: Behavioural information already incorporated in the analog.
# 7553: Behavioural information already incorporated in the analog.

# %%
for rec in recs.values():
    rec.peak_delay_amp()
    rec.auc()

# %% [markdown]
# # Comparison of a parameter between groups according to stimulation detection
#
# ---

# %%
def group_comp_param(recs, parameter, ko_hypo_only=False, stim_ampl="all", ylim=[]):
    fig, axs = plt.subplots(2, 4, figsize=(24, 16), constrained_layout=True)
    for i, neuron_type in enumerate(["EXC", "INH"]):
        for j, response_type in enumerate([-1, 1]):
            auto_ylim = ylim
            if ylim != [] and response_type == -1 and parameter != "Peak_delay":
                auto_ylim = [-i for i in ylim][::-1]
            wt_det, wt_undet, ko_det, ko_undet = [], [], [], []
            if ko_hypo_only:
                ko_type = "KO-Hypo"
                color_ko = ppt.hypo_color
                light_color_ko = ppt.hypo_light_color
            else:
                ko_type = "(KO + KO-Hypo)"
                color_ko = ppt.all_ko_color
                light_color_ko = ppt.all_ko_light_color

            for rec in recs.values():
                if ko_hypo_only and rec.genotype == "KO":
                    continue
                else:
                    # Filtering stimulation amplitudes
                    stim_filter = rec.stim_ampl_filter(stim_ampl)

                    # Responsivity and parameter matrices building or retrieving according to neuron type
                    resp_mat = rec.matrices[neuron_type]["Responsivity"]
                    para_mat = rec.matrices[neuron_type][parameter]


                    # For detected stimuli
                    stim_thre_det = np.logical_and(stim_filter, rec.detected_stim)
                    resp_detected = resp_mat[:,stim_thre_det]
                    detected = para_mat[:,stim_thre_det]
                    det = np.where(resp_detected == response_type, detected, np.nan)

                    # For undetected stimuli
                    stim_thre_undet = np.logical_and(stim_filter, np.invert(rec.detected_stim))
                    resp_undetected = resp_mat[:,stim_thre_undet]
                    undetected = para_mat[:,stim_thre_undet]
                    undet = np.where(resp_undetected == response_type, undetected, np.nan)

                    if rec.genotype == "WT":
                        wt_det.append(np.nanmean(np.nanmean(det, axis=1)))
                        wt_undet.append(np.nanmean(np.nanmean(undet, axis=1)))
                    else:
                        ko_det.append(np.nanmean(np.nanmean(det, axis=1)))
                        ko_undet.append(np.nanmean(np.nanmean(undet, axis=1)))

            ppt.boxplot(axs[i, 2*j], wt_det, ko_det, paired=False, ylabel=f"{parameter}", ylim=auto_ylim, colors=[ppt.wt_color, color_ko], det_marker=True)
            ppt.boxplot(axs[i, 2*j+1], wt_undet, ko_undet, paired=False, ylabel=f"{parameter}", ylim=auto_ylim, colors=[ppt.wt_light_color, light_color_ko], det_marker=False)
            axs[i, 2*j].set_title(f"Det {neuron_type}({response_type})")
            axs[i, 2*j+1].set_title(f"Undet {neuron_type}({response_type})")
    title = f"{parameter}[WT_{ko_type}]_{stim_ampl}_amp"
    fig.suptitle(f"Mean {parameter} between WT and {ko_type}. Amplitude(s): {stim_ampl}", fontsize=10)
    fig.canvas.manager.set_window_title(title)
    if save_figure:
        save_path = server_address + f"Figure-2/response_characterization/"
        fig.savefig(save_path + title, format="pdf")

# %% [markdown]
# ## AUC

# %% [markdown]
# ### All amplitudes

# %%
group_comp_param(recs, parameter="AUC", ko_hypo_only=True, stim_ampl="all", ylim=[0, 1])
# Out:
# Boxplot plotting.
# --- AUC:  ---
# ShapiroResult(statistic=0.8836701700158336, pvalue=0.09768277264760053)
# ShapiroResult(statistic=0.8801047826082176, pvalue=0.15741920487847827)
# LeveneResult(statistic=1.4225430394991205, pvalue=0.24766795588140472)
# Equal variances :TtestResult(statistic=0.34676217662908526, pvalue=0.7325809754738739, df=19.0)
# Boxplot plotting.
# --- AUC:  ---
# ShapiroResult(statistic=0.8998005339100541, pvalue=0.15768187339427991)
# ShapiroResult(statistic=0.9562692465494966, pvalue=0.7585818826262534)
# LeveneResult(statistic=1.5672827676289127, pvalue=0.2257951872950841)
# Equal variances :TtestResult(statistic=-1.642888826689281, pvalue=0.11685282924919993, df=19.0)
# Boxplot plotting.
# --- AUC:  ---
# ShapiroResult(statistic=0.966341078306835, pvalue=0.8689619234807242)
# ShapiroResult(statistic=0.9395124371609128, pvalue=0.5767756109237863)
# LeveneResult(statistic=0.8235590088561484, pvalue=0.3755083769828853)
# Equal variances :TtestResult(statistic=-0.36998226727589856, pvalue=0.7154876678511344, df=19.0)
# Boxplot plotting.
# --- AUC:  ---
# ShapiroResult(statistic=0.928587145376863, pvalue=0.3653772829167395)
# ShapiroResult(statistic=0.8463551874763464, pvalue=0.06793030771693129)
# LeveneResult(statistic=1.1634128281112872, pvalue=0.29426248701376184)
# Equal variances :TtestResult(statistic=-0.2633188091118911, pvalue=0.795139323993897, df=19.0)
# Boxplot plotting.
# --- AUC:  ---
# ShapiroResult(statistic=0.9188352650284202, pvalue=0.2764137106466277)
# ShapiroResult(statistic=0.9756734747793693, pvalue=0.9384294882500428)
# LeveneResult(statistic=8.701245975403227e-06, pvalue=0.9976788599602072)
# Equal variances :TtestResult(statistic=0.05899606150101297, pvalue=0.9536052905038109, df=18.0)
# Boxplot plotting.
# --- AUC:  ---
# ShapiroResult(statistic=0.9567978259989487, pvalue=0.73733179369484)
# ShapiroResult(statistic=0.7973083126736128, pvalue=0.026786179540488238)
# MannwhitneyuResult(statistic=42.0, pvalue=0.6784313725490196)
# Boxplot plotting.
# --- AUC:  ---
# ShapiroResult(statistic=0.8974402544558635, pvalue=0.14699799520669538)
# ShapiroResult(statistic=0.9093516028539339, pvalue=0.31136273350070603)
# LeveneResult(statistic=0.13736702514355542, pvalue=0.7150125734001985)
# Equal variances :TtestResult(statistic=-0.002469521933267552, pvalue=0.9980553532908341, df=19.0)
# Boxplot plotting.
# --- AUC:  ---
# ShapiroResult(statistic=0.6684985836920437, pvalue=0.00018495426365285034)
# ShapiroResult(statistic=0.9249965956655435, pvalue=0.4352041350040355)
# MannwhitneyuResult(statistic=59.0, pvalue=0.4941245444092638)

# %% [markdown]
# ### Threshold amplitude

# %%
group_comp_param(recs, parameter="AUC", ko_hypo_only=True, stim_ampl="threshold", ylim=[0, 1])

# %% [markdown]
# ### Amplitude 12

# %%
group_comp_param(recs, parameter="AUC", ko_hypo_only=True, stim_ampl=[12], ylim=[0, 1])

# %% [markdown]
# ### Subthreshold amplitudes

# %%
group_comp_param(recs, parameter="AUC", ko_hypo_only=True, stim_ampl="sub", ylim=[0, 1])

# %% [markdown]
# ### Suprathreshold amplitudes

# %%
group_comp_param(recs, parameter="AUC", ko_hypo_only=True, stim_ampl="supra", ylim=[0, 1])

# %% [markdown]
# ## Peak delay

# %% [markdown]
# ### All amplitudes

# %%
group_comp_param(recs, parameter="Peak_delay", ko_hypo_only=True, stim_ampl="all", ylim=[0, 15])
# Out:
# Boxplot plotting.
# --- Peak_delay:  ---
# ShapiroResult(statistic=0.9418370323767158, pvalue=0.5222316769917295)
# ShapiroResult(statistic=0.9252098374955366, pvalue=0.43710805262576147)
# LeveneResult(statistic=0.25949262659068134, pvalue=0.616334455973461)
# Equal variances :TtestResult(statistic=-1.666756211524053, pvalue=0.11196289893065264, df=19.0)
# Boxplot plotting.
# --- Peak_delay:  ---
# ShapiroResult(statistic=0.9376814771385396, pvalue=0.46863306747795214)
# ShapiroResult(statistic=0.9728115281795952, pvalue=0.917646990513279)
# LeveneResult(statistic=3.9226207410824396, pvalue=0.062306195366510816)
# Equal variances :TtestResult(statistic=-0.3117446599149866, pvalue=0.7586295705039322, df=19.0)
# Boxplot plotting.
# --- Peak_delay:  ---
# ShapiroResult(statistic=0.9420017690715281, pvalue=0.5244326438730283)
# ShapiroResult(statistic=0.8611867480092026, pvalue=0.09877466860168778)
# LeveneResult(statistic=0.921890566537046, pvalue=0.34903943496964296)
# Equal variances :TtestResult(statistic=-2.3444283274233046, pvalue=0.0300755652255044, df=19.0)
# Boxplot plotting.
# --- Peak_delay:  ---
# ShapiroResult(statistic=0.9083724942964279, pvalue=0.20333192594548444)
# ShapiroResult(statistic=0.9360804597433023, pvalue=0.5412977402760968)
# LeveneResult(statistic=1.016250377662331, pvalue=0.32607679934047434)
# Equal variances :TtestResult(statistic=0.28727940905283156, pvalue=0.7770081130354545, df=19.0)
# Boxplot plotting.
# --- Peak_delay:  ---
# ShapiroResult(statistic=0.9333194163296304, pvalue=0.416627543076762)
# ShapiroResult(statistic=0.8448212245123878, pvalue=0.08439023331580676)
# LeveneResult(statistic=0.857254226604153, pvalue=0.3667562736040282)
# Equal variances :TtestResult(statistic=0.2762630328015116, pvalue=0.7854930519759764, df=18.0)
# Boxplot plotting.
# --- Peak_delay:  ---
# ShapiroResult(statistic=0.916443731304276, pvalue=0.25781047084112896)
# ShapiroResult(statistic=0.9494898679935049, pvalue=0.7060865779710425)
# LeveneResult(statistic=7.017585035994671, pvalue=0.01632084032043861)
# Unequal variances: TtestResult(statistic=1.4276288993610338, pvalue=0.1705184650072195, df=18.0)
# Boxplot plotting.
# --- Peak_delay:  ---
# ShapiroResult(statistic=0.9634167929147723, pvalue=0.8312635280050764)
# ShapiroResult(statistic=0.904567074323858, pvalue=0.27967785848805515)
# LeveneResult(statistic=4.183463128598934e-05, pvalue=0.9949067725000598)
# Equal variances :TtestResult(statistic=0.12848668053576745, pvalue=0.8991141304832359, df=19.0)
# Boxplot plotting.
# --- Peak_delay:  ---
# ShapiroResult(statistic=0.9386773131956976, pvalue=0.5050754869680966)
# ShapiroResult(statistic=0.9291076215242271, pvalue=0.4728953887457821)
# LeveneResult(statistic=0.6834965904744591, pvalue=0.41921022184276124)
# Equal variances :TtestResult(statistic=0.18272765451042186, pvalue=0.8570540388951333, df=18.0)

# %% [markdown]
# ### Threshold amplitude

# %%
group_comp_param(recs, parameter="Peak_delay", ko_hypo_only=True, stim_ampl="threshold", ylim=[0, 15])
# Out:
# Boxplot plotting.
# --- Peak_delay:  ---
# ShapiroResult(statistic=0.8783464126468059, pvalue=0.09912939041188634)
# ShapiroResult(statistic=0.9444069767056918, pvalue=0.6289757919539825)
# LeveneResult(statistic=0.12496107975028779, pvalue=0.727821312857476)
# Equal variances :TtestResult(statistic=-0.3319620625123569, pvalue=0.7437521225457635, df=18.0)
# Boxplot plotting.
# --- Peak_delay:  ---
# ShapiroResult(statistic=0.9210166758679673, pvalue=0.2944450902375588)
# ShapiroResult(statistic=0.9451990080579828, pvalue=0.637559575712555)
# LeveneResult(statistic=0.40552811347162115, pvalue=0.5318463658711923)
# Equal variances :TtestResult(statistic=0.5483996273788175, pvalue=0.5898038247980981, df=19.0)
# Boxplot plotting.
# --- Peak_delay:  ---
# ShapiroResult(statistic=0.9569733186950726, pvalue=0.739911314960491)
# ShapiroResult(statistic=0.929728133243171, pvalue=0.47876150622191216)
# LeveneResult(statistic=0.700413818307294, pvalue=0.4130477786514818)
# Equal variances :TtestResult(statistic=-0.14358667884533294, pvalue=0.8873388034366394, df=19.0)
# Boxplot plotting.
# --- Peak_delay:  ---
# ShapiroResult(statistic=0.9508753468362594, pvalue=0.6498161019458837)
# ShapiroResult(statistic=0.9895658209859987, pvalue=0.9954711152636933)
# LeveneResult(statistic=0.3903886193930203, pvalue=0.5395269251965338)
# Equal variances :TtestResult(statistic=-1.4179150105190867, pvalue=0.17240843714152998, df=19.0)
# Boxplot plotting.
# --- Peak_delay:  ---
# ShapiroResult(statistic=0.8014795775392771, pvalue=0.015111332521184734)
# ShapiroResult(statistic=0.9826424867237133, pvalue=0.9713648291271635)
# MannwhitneyuResult(statistic=35.5, pvalue=1.0)
# Boxplot plotting.
# --- Peak_delay:  ---
# ShapiroResult(statistic=0.9686574177734728, pvalue=0.8962415278092902)
# ShapiroResult(statistic=0.9190564944222175, pvalue=0.49859158803450787)
# LeveneResult(statistic=0.6515567510381229, pvalue=0.4313931936231654)
# Equal variances :TtestResult(statistic=2.0144837526460933, pvalue=0.06108556112361191, df=16.0)
# Boxplot plotting.
# --- Peak_delay:  ---
# ShapiroResult(statistic=0.9150538529564678, pvalue=0.2795701498852098)
# ShapiroResult(statistic=0.9328937411966238, pvalue=0.5093779616189109)
# LeveneResult(statistic=3.3863710991574543, pvalue=0.08228652715789175)
# Equal variances :TtestResult(statistic=-1.4390624367833666, pvalue=0.16729609824186814, df=18.0)
# Boxplot plotting.
# --- Peak_delay:  ---
# ShapiroResult(statistic=0.9202524780906083, pvalue=0.3207485132030725)
# ShapiroResult(statistic=0.9511253738938652, pvalue=0.7024232163393574)
# LeveneResult(statistic=0.6987488743610764, pvalue=0.414163584587679)
# Equal variances :TtestResult(statistic=0.21845426986849797, pvalue=0.8295328263014878, df=18.0)

# %% [markdown]
# ### Amplitude 12

# %%
group_comp_param(recs, parameter="Peak_delay", ko_hypo_only=True, stim_ampl=[12], ylim=[0, 15])

# %% [markdown]
# ### Subthreshold amplitudes

# %%
group_comp_param(recs, parameter="Peak_delay", ko_hypo_only=True, stim_ampl="sub", ylim=[0, 15])

# %% [markdown]
# ### Suprathreshold amplitudes

# %%
group_comp_param(recs, parameter="Peak_delay", ko_hypo_only=True, stim_ampl="supra", ylim=[0, 15])

# %% [markdown]
# ## Peak amplitude

# %% [markdown]
# ### All amplitude

# %%
group_comp_param(recs, parameter="Peak_amplitude", ko_hypo_only=True, stim_ampl="all", ylim=[0, 5])
# Out:
# Boxplot plotting.
# --- Peak_amplitude:  ---
# ShapiroResult(statistic=0.8317282657895725, pvalue=0.021997515160463752)
# ShapiroResult(statistic=0.7326337626288428, pvalue=0.003407498078096824)
# MannwhitneyuResult(statistic=30.0, pvalue=0.0949050641750451)
# Boxplot plotting.
# --- Peak_amplitude:  ---
# ShapiroResult(statistic=0.9584115103424952, pvalue=0.760934945997628)
# ShapiroResult(statistic=0.8472491667720105, pvalue=0.06949311966095043)
# LeveneResult(statistic=0.08589107337045843, pvalue=0.7726441533616172)
# Equal variances :TtestResult(statistic=-2.115528500183421, pvalue=0.047818731478352895, df=19.0)
# Boxplot plotting.
# --- Peak_amplitude:  ---
# ShapiroResult(statistic=0.8837088091115516, pvalue=0.09779448484949052)
# ShapiroResult(statistic=0.91350201994978, pvalue=0.341160450064634)
# LeveneResult(statistic=0.5477644140847382, pvalue=0.468280142519541)
# Equal variances :TtestResult(statistic=0.7418399539291186, pvalue=0.46725620929498113, df=19.0)
# Boxplot plotting.
# --- Peak_amplitude:  ---
# ShapiroResult(statistic=0.9274596091841566, pvalue=0.3539620357313189)
# ShapiroResult(statistic=0.9291199941819078, pvalue=0.4730119117253567)
# LeveneResult(statistic=0.06119807493543251, pvalue=0.8072657964684581)
# Equal variances :TtestResult(statistic=-1.299193128233097, pvalue=0.2094226343525029, df=19.0)
# Boxplot plotting.
# --- Peak_amplitude:  ---
# ShapiroResult(statistic=0.8805486718246983, pvalue=0.08907671346091997)
# ShapiroResult(statistic=0.9133580971609379, pvalue=0.3783182795658923)
# LeveneResult(statistic=0.02218619911585612, pvalue=0.8832489218862873)
# Equal variances :TtestResult(statistic=-0.35980965782610436, pvalue=0.7231764083590917, df=18.0)
# Boxplot plotting.
# --- Peak_amplitude:  ---
# ShapiroResult(statistic=0.9412328326211024, pvalue=0.514207038284212)
# ShapiroResult(statistic=0.8845813534377809, pvalue=0.20819052667012922)
# LeveneResult(statistic=0.011985023789712324, pvalue=0.9140361238003486)
# Equal variances :TtestResult(statistic=-0.2934169431521311, pvalue=0.7725596022999026, df=18.0)
# Boxplot plotting.
# --- Peak_amplitude:  ---
# ShapiroResult(statistic=0.9265289442445285, pvalue=0.34476817113865266)
# ShapiroResult(statistic=0.8321746689214995, pvalue=0.04723251385312736)
# MannwhitneyuResult(statistic=51.0, pvalue=0.8589842960089598)
# Boxplot plotting.
# --- Peak_amplitude:  ---
# ShapiroResult(statistic=0.9326618252877682, pvalue=0.4384042704206439)
# ShapiroResult(statistic=0.9736054651028891, pvalue=0.923683679552187)
# LeveneResult(statistic=8.428845831201315, pvalue=0.009478671923927212)
# Unequal variances: TtestResult(statistic=-0.22568926849406465, pvalue=0.8239857962860576, df=18.0)

# %% [markdown]
# ### Threshold amplitude

# %%
group_comp_param(recs, parameter="Peak_amplitude", ko_hypo_only=True, stim_ampl="threshold", ylim=[0, 5])
# Out:
# Boxplot plotting.
# --- Peak_amplitude:  ---
# ShapiroResult(statistic=0.856464432700491, pvalue=0.051807175515541606)
# ShapiroResult(statistic=0.9465258097481507, pvalue=0.652001583115128)
# LeveneResult(statistic=0.07465890547681577, pvalue=0.7877807611580604)
# Equal variances :TtestResult(statistic=-2.207038311778465, pvalue=0.04053571240688213, df=18.0)
# Boxplot plotting.
# --- Peak_amplitude:  ---
# ShapiroResult(statistic=0.6933600848731315, pvalue=0.0007278119586562632)
# ShapiroResult(statistic=0.8022813095710207, pvalue=0.021682707459596617)
# MannwhitneyuResult(statistic=37.0, pvalue=0.24095466870157012)
# Boxplot plotting.
# --- Peak_amplitude:  ---
# ShapiroResult(statistic=0.8439606602002534, pvalue=0.030944846714055476)
# ShapiroResult(statistic=0.9417106189821877, pvalue=0.600016959269146)
# MannwhitneyuResult(statistic=76.0, pvalue=0.1265278162606013)
# Boxplot plotting.
# --- Peak_amplitude:  ---
# ShapiroResult(statistic=0.8001993367876468, pvalue=0.00941791765443268)
# ShapiroResult(statistic=0.9051627222014048, pvalue=0.28347015120633645)
# MannwhitneyuResult(statistic=41.0, pvalue=0.37435986931078846)
# Boxplot plotting.
# --- Peak_amplitude:  ---
# ShapiroResult(statistic=0.9813506486451513, pvalue=0.9719838938378907)
# ShapiroResult(statistic=0.8669097381696248, pvalue=0.1743837274976872)
# LeveneResult(statistic=1.5524133754929277, pvalue=0.23188938230408299)
# Equal variances :TtestResult(statistic=-0.05760290890154738, pvalue=0.954825280634763, df=15.0)
# Boxplot plotting.
# --- Peak_amplitude:  ---
# ShapiroResult(statistic=0.9271375792511088, pvalue=0.3507574913327416)
# ShapiroResult(statistic=0.9968514584239656, pvalue=0.9992778265660657)
# LeveneResult(statistic=0.8171084896910351, pvalue=0.3794361182522168)
# Equal variances :TtestResult(statistic=0.5226424857456615, pvalue=0.6083847498312698, df=16.0)
# Boxplot plotting.
# --- Peak_amplitude:  ---
# ShapiroResult(statistic=0.9526878125491295, pvalue=0.6784373145690776)
# ShapiroResult(statistic=0.9118832296584973, pvalue=0.3292788106359669)
# LeveneResult(statistic=0.006688787738452734, pvalue=0.9357202407105137)
# Equal variances :TtestResult(statistic=0.2644783412566762, pvalue=0.7944159437451213, df=18.0)
# Boxplot plotting.
# --- Peak_amplitude:  ---
# ShapiroResult(statistic=0.8768209071604002, pvalue=0.09479081452474965)
# ShapiroResult(statistic=0.8895599513123567, pvalue=0.19745868748999218)
# LeveneResult(statistic=2.492957981786444, pvalue=0.13176876575552515)
# Equal variances :TtestResult(statistic=-0.14195392423263142, pvalue=0.8886931786286894, df=18.0)

# %% [markdown]
# ### Amplitude 12

# %%
group_comp_param(recs, parameter="Peak_amplitude", ko_hypo_only=True, stim_ampl=[12], ylim=[0, 5])

# %% [markdown]
# ### Subthreshold amplitudes

# %%
group_comp_param(recs, parameter="Peak_amplitude", ko_hypo_only=True, stim_ampl="sub", ylim=[0, 5])

# %% [markdown]
# ### Suprathreshold amplitudes

# %%
group_comp_param(recs, parameter="Peak_amplitude", ko_hypo_only=True, stim_ampl="supra", ylim=[0, 5])

# %% [markdown]
# # Comparison of a parameter between detected and undetected stimulation according to group
#
# ---

# %%
def det_comp_param(recs, parameter, stim_ampl="all", ylim=[]):
    fig, axs = plt.subplots(2, 6, figsize=(36, 16), constrained_layout=True)
    for i, neuron_type in enumerate(["EXC", "INH"]):
        for j, response_type in enumerate([-1, 1]):
            auto_ylim = ylim
            if ylim != [] and response_type == -1 and parameter != "Peak_delay":
                auto_ylim = [-i for i in ylim][::-1]
            wt_det, wt_undet, ko_det, ko_undet, hypo_det, hypo_undet = [], [], [], [], [], []
            
            for rec in recs.values():
                # Filtering of stimulations
                stim_filter = rec.stim_ampl_filter(stim_ampl)
                
                # Responsivity and parameter matrices building or retrieving according to neuron type
                resp_mat = rec.matrices[neuron_type]["Responsivity"]
                para_mat = rec.matrices[neuron_type][parameter]

                
                # For detected stimuli
                stim_thre_det = np.logical_and(stim_filter, rec.detected_stim)
                resp_detected = resp_mat[:,stim_thre_det]
                detected = para_mat[:,stim_thre_det]
                det = np.where(resp_detected == response_type, detected, np.nan)
                
                # For undetected stimuli
                stim_thre_undet = np.logical_and(stim_filter, np.invert(rec.detected_stim))
                resp_undetected = resp_mat[:,stim_thre_undet]
                undetected = para_mat[:,stim_thre_undet]
                undet = np.where(resp_undetected == response_type, undetected, np.nan)
                
                if rec.genotype == "WT":
                    wt_det.append(np.nanmean(np.nanmean(det, axis=1)))
                    wt_undet.append(np.nanmean(np.nanmean(undet, axis=1)))
                else:
                    ko_det.append(np.nanmean(np.nanmean(np.nanmean(det, axis=1))))
                    ko_undet.append(np.nanmean(np.nanmean(undet, axis=1)))
                if rec.genotype == "KO-Hypo":
                    hypo_det.append(np.nanmean(np.nanmean(np.nanmean(det, axis=1))))
                    hypo_undet.append(np.nanmean(np.nanmean(undet, axis=1)))
                
            ppt.boxplot(axs[i, 3*j], wt_det, wt_undet, ylabel=parameter, paired=True, title=f"WT {neuron_type}({response_type})", ylim=auto_ylim, 
                        colors=[ppt.wt_color, ppt.wt_light_color])
            ppt.boxplot(axs[i, 3*j+1], ko_det, ko_undet, ylabel=parameter, paired=True, title=f"KO + KO-Hypo {neuron_type}({response_type})", ylim=auto_ylim, 
                        colors=[ppt.all_ko_color, ppt.all_ko_light_color])
            ppt.boxplot(axs[i, 3*j+2], hypo_det, hypo_undet, ylabel=parameter, paired=True, title=f"KO-Hypo {neuron_type}({response_type})", ylim=auto_ylim, 
                        colors=[ppt.hypo_color, ppt.hypo_light_color])
            # excel_df_WT = pd.DataFrame(data={"WT Det": wt_det, "WT Undet": wt_undet})
            # excel_df_KO = pd.DataFrame(data={"Hypo Det": hypo_det, "Hypo Undet": hypo_undet})
            # excel_df_WT.to_csv(f"{server_address}data/det_{parameter}_{neuron_type}_{stim_ampl}_{response_type}_WT.csv", sep=",")
            # excel_df_KO.to_csv(f"{server_address}data/det_{parameter}_{neuron_type}_{stim_ampl}_{response_type}_KO.csv", sep=",")
    title = f"{parameter}[det_undet]_{stim_ampl}_amp"
    fig.suptitle(f"Mean {parameter} for detected vs. undetected stimuli. Amplitude(s): {stim_ampl}", fontsize=10)
    fig.canvas.manager.set_window_title(title)
    if save_figure:
        save_path = server_address + f"Figure_2/"
        fig.savefig(save_path + title, format="pdf")

# %% [markdown]
# ## AUC

# %% [markdown]
# ### All amplitudes

# %%
det_comp_param(recs, "AUC", stim_ampl="all", ylim=[0, 1])
# Out:
# Boxplot plotting.
# --- AUC: WT EXC(-1) ---
# ShapiroResult(statistic=0.8836701700158336, pvalue=0.09768277264760053)
# ShapiroResult(statistic=0.8998005339100541, pvalue=0.15768187339427991)
# TtestResult(statistic=4.777812561623154, pvalue=0.0005734276449607251, df=11)
# Boxplot plotting.
# --- AUC: KO + KO-Hypo EXC(-1) ---
# ShapiroResult(statistic=0.8822889438388347, pvalue=0.06265288131664457)
# ShapiroResult(statistic=0.9752877324412464, pvalue=0.9382391234252591)
# TtestResult(statistic=3.3078187214255603, pvalue=0.005661908399954848, df=13)
# Boxplot plotting.
# --- AUC: KO-Hypo EXC(-1) ---
# ShapiroResult(statistic=0.8801047826082176, pvalue=0.15741920487847827)
# ShapiroResult(statistic=0.9562692465494966, pvalue=0.7585818826262534)
# TtestResult(statistic=3.148956160159986, pvalue=0.013619906296970704, df=8)
# Boxplot plotting.
# --- AUC: WT EXC(1) ---
# ShapiroResult(statistic=0.966341078306835, pvalue=0.8689619234807242)
# ShapiroResult(statistic=0.928587145376863, pvalue=0.3653772829167395)
# TtestResult(statistic=-1.1246634967992142, pvalue=0.28467424148203885, df=11)
# Boxplot plotting.
# --- AUC: KO + KO-Hypo EXC(1) ---
# ShapiroResult(statistic=0.9337084755051477, pvalue=0.34365873007480324)
# ShapiroResult(statistic=0.8893190731268058, pvalue=0.07902767087159386)
# TtestResult(statistic=-1.3776298381019159, pvalue=0.1915722290344369, df=13)
# Boxplot plotting.
# --- AUC: KO-Hypo EXC(1) ---
# ShapiroResult(statistic=0.9395124371609128, pvalue=0.5767756109237863)
# ShapiroResult(statistic=0.8463551874763464, pvalue=0.06793030771693129)
# TtestResult(statistic=-1.5193246666102214, pvalue=0.16716564291986583, df=8)
# Boxplot plotting.
# --- AUC: WT INH(-1) ---
# ShapiroResult(statistic=0.9188352650284202, pvalue=0.2764137106466277)
# ShapiroResult(statistic=0.9567978259989487, pvalue=0.73733179369484)
# TtestResult(statistic=0.6402714064045004, pvalue=0.5351054493258552, df=11)
# Boxplot plotting.
# --- AUC: KO + KO-Hypo INH(-1) ---
# ShapiroResult(statistic=0.9768234580540046, pvalue=0.967737524756864)
# ShapiroResult(statistic=0.8863591157147952, pvalue=0.10577732305228038)
# TtestResult(statistic=1.0261566452205446, pvalue=0.32685461242646285, df=11)
# Boxplot plotting.
# --- AUC: KO-Hypo INH(-1) ---
# ShapiroResult(statistic=0.9756734747793693, pvalue=0.9384294882500428)
# ShapiroResult(statistic=0.7973083126736128, pvalue=0.026786179540488238)
# WilcoxonResult(statistic=12.0, pvalue=0.4609375)
# Boxplot plotting.
# --- AUC: WT INH(1) ---
# ShapiroResult(statistic=0.8721272865122911, pvalue=0.08255354201503386)
# ShapiroResult(statistic=0.6684985836920437, pvalue=0.00018495426365285034)
# WilcoxonResult(statistic=11.0, pvalue=0.0537109375)
# Boxplot plotting.
# --- AUC: KO + KO-Hypo INH(1) ---
# ShapiroResult(statistic=0.8578596568977703, pvalue=0.028445762237390513)
# ShapiroResult(statistic=0.9051580901406409, pvalue=0.13401878143505164)
# WilcoxonResult(statistic=36.0, pvalue=0.3258056640625)
# Boxplot plotting.
# --- AUC: KO-Hypo INH(1) ---
# ShapiroResult(statistic=0.9093516028539339, pvalue=0.31136273350070603)
# ShapiroResult(statistic=0.9249965956655435, pvalue=0.4352041350040355)
# TtestResult(statistic=-0.8943784984152733, pvalue=0.39722836575029763, df=8)

# %% [markdown]
# ### Threshold amplitude

# %%
det_comp_param(recs, "AUC", stim_ampl="threshold", ylim=[0, 1])

# %% [markdown]
# ### Amplitude 12

# %%
det_comp_param(recs, "AUC", stim_ampl=[12], ylim=[0, 1])

# %% [markdown]
# ### Subtreshold amplitudes

# %%
det_comp_param(recs, "AUC", stim_ampl="sub", ylim=[0, 1])

# %% [markdown]
# ### Suprathreshold amplitudes

# %%
det_comp_param(recs, "AUC", stim_ampl="supra", ylim=[0, 1])

# %% [markdown]
# ## Peak delay

# %% [markdown]
# ### All amplitudes

# %%
det_comp_param(recs, "Peak_delay", stim_ampl="all", ylim=[0, 15])
# Out:
# Boxplot plotting.
# --- Peak_delay: WT EXC(-1) ---
# ShapiroResult(statistic=0.9418370323767158, pvalue=0.5222316769917295)
# ShapiroResult(statistic=0.9376814771385396, pvalue=0.46863306747795214)
# TtestResult(statistic=-4.816770904321178, pvalue=0.000538660020623428, df=11)
# Boxplot plotting.
# --- Peak_delay: KO + KO-Hypo EXC(-1) ---
# ShapiroResult(statistic=0.8764915639192281, pvalue=0.05181253244636156)
# ShapiroResult(statistic=0.9491731135833525, pvalue=0.5479427338152378)
# TtestResult(statistic=-4.173072376573642, pvalue=0.001093096267474268, df=13)
# Boxplot plotting.
# --- Peak_delay: KO-Hypo EXC(-1) ---
# ShapiroResult(statistic=0.9252098374955366, pvalue=0.43710805262576147)
# ShapiroResult(statistic=0.9728115281795952, pvalue=0.917646990513279)
# TtestResult(statistic=-2.537860530479981, pvalue=0.034826582664955544, df=8)
# Boxplot plotting.
# --- Peak_delay: WT EXC(1) ---
# ShapiroResult(statistic=0.9420017690715281, pvalue=0.5244326438730283)
# ShapiroResult(statistic=0.9083724942964279, pvalue=0.20333192594548444)
# TtestResult(statistic=-3.7389019759104563, pvalue=0.0032724208591014665, df=11)
# Boxplot plotting.
# --- Peak_delay: KO + KO-Hypo EXC(1) ---
# ShapiroResult(statistic=0.9282552482207352, pvalue=0.2883776356177439)
# ShapiroResult(statistic=0.8560708723555244, pvalue=0.02688006526883944)
# WilcoxonResult(statistic=26.0, pvalue=0.10400390625)
# Boxplot plotting.
# --- Peak_delay: KO-Hypo EXC(1) ---
# ShapiroResult(statistic=0.8611867480092026, pvalue=0.09877466860168778)
# ShapiroResult(statistic=0.9360804597433023, pvalue=0.5412977402760968)
# TtestResult(statistic=-0.8267249128383221, pvalue=0.43235760603262874, df=8)
# Boxplot plotting.
# --- Peak_delay: WT INH(-1) ---
# ShapiroResult(statistic=0.9333194163296304, pvalue=0.416627543076762)
# ShapiroResult(statistic=0.916443731304276, pvalue=0.25781047084112896)
# TtestResult(statistic=-2.395592938552216, pvalue=0.03550836295025045, df=11)
# Boxplot plotting.
# --- Peak_delay: KO + KO-Hypo INH(-1) ---
# ShapiroResult(statistic=0.7392306660697169, pvalue=0.0020675579394206747)
# ShapiroResult(statistic=0.9632382996683132, pvalue=0.8288642870369856)
# WilcoxonResult(statistic=26.0, pvalue=0.33935546875)
# Boxplot plotting.
# --- Peak_delay: KO-Hypo INH(-1) ---
# ShapiroResult(statistic=0.8448212245123878, pvalue=0.08439023331580676)
# ShapiroResult(statistic=0.9494898679935049, pvalue=0.7060865779710425)
# TtestResult(statistic=-0.9304554099293758, pvalue=0.3831025429203175, df=7)
# Boxplot plotting.
# --- Peak_delay: WT INH(1) ---
# ShapiroResult(statistic=0.9338041796002486, pvalue=0.4506049263891885)
# ShapiroResult(statistic=0.9386773131956976, pvalue=0.5050754869680966)
# TtestResult(statistic=-1.4315886655418166, pvalue=0.18276490539809923, df=10)
# Boxplot plotting.
# --- Peak_delay: KO + KO-Hypo INH(1) ---
# ShapiroResult(statistic=0.946011826493427, pvalue=0.5006677551093401)
# ShapiroResult(statistic=0.8328379462168427, pvalue=0.013095478332932172)
# WilcoxonResult(statistic=17.0, pvalue=0.0245361328125)
# Boxplot plotting.
# --- Peak_delay: KO-Hypo INH(1) ---
# ShapiroResult(statistic=0.904567074323858, pvalue=0.27967785848805515)
# ShapiroResult(statistic=0.9291076215242271, pvalue=0.4728953887457821)
# TtestResult(statistic=-1.8173414847132805, pvalue=0.10668538249667521, df=8)

# %% [markdown]
# ### Threshold amplitude

# %%
det_comp_param(recs, "Peak_delay", stim_ampl="threshold", ylim=[0, 15])
# Out:
# Boxplot plotting.
# --- Peak_delay: WT EXC(-1) ---
# ShapiroResult(statistic=0.8783464126468059, pvalue=0.09912939041188634)
# ShapiroResult(statistic=0.9393894927096996, pvalue=0.5133476840932297)
# TtestResult(statistic=-2.173855498110081, pvalue=0.05481174531158344, df=10)
# Boxplot plotting.
# --- Peak_delay: KO + KO-Hypo EXC(-1) ---
# ShapiroResult(statistic=0.9426302062457225, pvalue=0.45306095709065647)
# ShapiroResult(statistic=0.9143025404075067, pvalue=0.18194218650069272)
# TtestResult(statistic=-1.2777841581388936, pvalue=0.22367203741769276, df=13)
# Boxplot plotting.
# --- Peak_delay: KO-Hypo EXC(-1) ---
# ShapiroResult(statistic=0.9444069767056918, pvalue=0.6289757919539825)
# ShapiroResult(statistic=0.9451990080579828, pvalue=0.637559575712555)
# TtestResult(statistic=-0.527869819824457, pvalue=0.6119132605650617, df=8)
# Boxplot plotting.
# --- Peak_delay: WT EXC(1) ---
# ShapiroResult(statistic=0.9569733186950726, pvalue=0.739911314960491)
# ShapiroResult(statistic=0.9508753468362594, pvalue=0.6498161019458837)
# TtestResult(statistic=-0.2650855022688491, pvalue=0.7958453957745741, df=11)
# Boxplot plotting.
# --- Peak_delay: KO + KO-Hypo EXC(1) ---
# ShapiroResult(statistic=0.9216429875508214, pvalue=0.2321776280135232)
# ShapiroResult(statistic=0.9289762618426232, pvalue=0.29520382625546404)
# TtestResult(statistic=-1.9264036065074455, pvalue=0.07620136957297553, df=13)
# Boxplot plotting.
# --- Peak_delay: KO-Hypo EXC(1) ---
# ShapiroResult(statistic=0.929728133243171, pvalue=0.47876150622191216)
# ShapiroResult(statistic=0.9895658209859987, pvalue=0.9954711152636933)
# TtestResult(statistic=-1.4274465380618468, pvalue=0.19129755287377434, df=8)
# Boxplot plotting.
# --- Peak_delay: WT INH(-1) ---
# ShapiroResult(statistic=0.8014795775392771, pvalue=0.015111332521184734)
# ShapiroResult(statistic=0.9623752990999777, pvalue=0.8125815455133774)
# WilcoxonResult(statistic=20.0, pvalue=0.4921875)
# Boxplot plotting.
# --- Peak_delay: KO + KO-Hypo INH(-1) ---
# ShapiroResult(statistic=0.9636659698453102, pvalue=0.8267256770435123)
# ShapiroResult(statistic=0.85776415743012, pvalue=0.0718089054829915)
# TtestResult(statistic=2.226155610258485, pvalue=0.05302856014404076, df=9)
# Boxplot plotting.
# --- Peak_delay: KO-Hypo INH(-1) ---
# ShapiroResult(statistic=0.9608077710240259, pvalue=0.8259441515633019)
# ShapiroResult(statistic=0.9190564944222175, pvalue=0.49859158803450787)
# TtestResult(statistic=3.4622561662852522, pvalue=0.01799857236176897, df=5)
# Boxplot plotting.
# --- Peak_delay: WT INH(1) ---
# ShapiroResult(statistic=0.9225178376422383, pvalue=0.3784341897979275)
# ShapiroResult(statistic=0.9167389498085761, pvalue=0.33055719152490626)
# TtestResult(statistic=-0.840143195560984, pvalue=0.4225848518694759, df=9)
# Boxplot plotting.
# --- Peak_delay: KO + KO-Hypo INH(1) ---
# ShapiroResult(statistic=0.9487398952605323, pvalue=0.5413186123431104)
# ShapiroResult(statistic=0.9642804132412134, pvalue=0.7924306113608746)
# TtestResult(statistic=0.14488459271010698, pvalue=0.8870241588086014, df=13)
# Boxplot plotting.
# --- Peak_delay: KO-Hypo INH(1) ---
# ShapiroResult(statistic=0.9328937411966238, pvalue=0.5093779616189109)
# ShapiroResult(statistic=0.9511253738938652, pvalue=0.7024232163393574)
# TtestResult(statistic=0.41140063970136465, pvalue=0.6915794344998523, df=8)

# %% [markdown]
# ### Amplitude 12

# %%
det_comp_param(recs, "Peak_delay", stim_ampl=[12], ylim=[0, 15])

# %% [markdown]
# ### Subthreshold amplitudes

# %%
det_comp_param(recs, "Peak_delay", stim_ampl="sub", ylim=[0, 15])

# %% [markdown]
# ### Suprathreshold amplitudes

# %%
det_comp_param(recs, "Peak_delay", stim_ampl="supra", ylim=[0, 15])

# %% [markdown]
# ## Peak amplitude

# %% [markdown]
# ### All amplitudes

# %%
det_comp_param(recs, "Peak_amplitude", stim_ampl="all", ylim=[0, 5])
# Out:
# Boxplot plotting.
# --- Peak_amplitude: WT EXC(-1) ---
# ShapiroResult(statistic=0.8317282657895725, pvalue=0.021997515160463752)
# ShapiroResult(statistic=0.9584115103424952, pvalue=0.760934945997628)
# WilcoxonResult(statistic=26.0, pvalue=0.33935546875)
# Boxplot plotting.
# --- Peak_amplitude: KO + KO-Hypo EXC(-1) ---
# ShapiroResult(statistic=0.673596129803913, pvalue=0.00019947381733139945)
# ShapiroResult(statistic=0.9303497441300798, pvalue=0.3086077164146745)
# WilcoxonResult(statistic=52.0, pvalue=1.0)
# Boxplot plotting.
# --- Peak_amplitude: KO-Hypo EXC(-1) ---
# ShapiroResult(statistic=0.7326337626288428, pvalue=0.003407498078096824)
# ShapiroResult(statistic=0.8472491667720105, pvalue=0.06949311966095043)
# WilcoxonResult(statistic=21.0, pvalue=0.91015625)
# Boxplot plotting.
# --- Peak_amplitude: WT EXC(1) ---
# ShapiroResult(statistic=0.8837088091115516, pvalue=0.09779448484949052)
# ShapiroResult(statistic=0.9274596091841566, pvalue=0.3539620357313189)
# TtestResult(statistic=2.156733762540831, pvalue=0.05401047094365168, df=11)
# Boxplot plotting.
# --- Peak_amplitude: KO + KO-Hypo EXC(1) ---
# ShapiroResult(statistic=0.9563504676068237, pvalue=0.6628189940087472)
# ShapiroResult(statistic=0.9369407741277836, pvalue=0.3805309934645518)
# TtestResult(statistic=-0.36584255133452204, pvalue=0.7203668212360457, df=13)
# Boxplot plotting.
# --- Peak_amplitude: KO-Hypo EXC(1) ---
# ShapiroResult(statistic=0.91350201994978, pvalue=0.341160450064634)
# ShapiroResult(statistic=0.9291199941819078, pvalue=0.4730119117253567)
# TtestResult(statistic=-1.0940752774137068, pvalue=0.30576662822382683, df=8)
# Boxplot plotting.
# --- Peak_amplitude: WT INH(-1) ---
# ShapiroResult(statistic=0.8805486718246983, pvalue=0.08907671346091997)
# ShapiroResult(statistic=0.9412328326211024, pvalue=0.514207038284212)
# TtestResult(statistic=-1.7851324227766232, pvalue=0.1018077233915255, df=11)
# Boxplot plotting.
# --- Peak_amplitude: KO + KO-Hypo INH(-1) ---
# ShapiroResult(statistic=0.9020572886835486, pvalue=0.168616950752685)
# ShapiroResult(statistic=0.9341852396795429, pvalue=0.42658976460597775)
# TtestResult(statistic=-0.40386005166838956, pvalue=0.6940559947020999, df=11)
# Boxplot plotting.
# --- Peak_amplitude: KO-Hypo INH(-1) ---
# ShapiroResult(statistic=0.9133580971609379, pvalue=0.3783182795658923)
# ShapiroResult(statistic=0.8845813534377809, pvalue=0.20819052667012922)
# TtestResult(statistic=-1.1335616987460766, pvalue=0.29430401530734573, df=7)
# Boxplot plotting.
# --- Peak_amplitude: WT INH(1) ---
# ShapiroResult(statistic=0.9356120286081022, pvalue=0.4703636104996944)
# ShapiroResult(statistic=0.9326618252877682, pvalue=0.4384042704206439)
# TtestResult(statistic=-0.13075203369836352, pvalue=0.8985644390896559, df=10)
# Boxplot plotting.
# --- Peak_amplitude: KO + KO-Hypo INH(1) ---
# ShapiroResult(statistic=0.927638041972937, pvalue=0.2826474848591057)
# ShapiroResult(statistic=0.9374527500426302, pvalue=0.3866590909449822)
# TtestResult(statistic=-1.373063805878786, pvalue=0.19295310287965697, df=13)
# Boxplot plotting.
# --- Peak_amplitude: KO-Hypo INH(1) ---
# ShapiroResult(statistic=0.8321746689214995, pvalue=0.04723251385312736)
# ShapiroResult(statistic=0.9736054651028891, pvalue=0.923683679552187)
# WilcoxonResult(statistic=14.0, pvalue=0.359375)

# %% [markdown]
# ### Threshold amplitude

# %%
det_comp_param(recs, "Peak_amplitude", stim_ampl="threshold", ylim=[0, 5])

# %% [markdown]
# ### Amplitude 12

# %%
det_comp_param(recs, "Peak_amplitude", stim_ampl=[12], ylim=[0, 5])

# %% [markdown]
# ### Subtreshold amplitudes

# %%
det_comp_param(recs, "Peak_amplitude", stim_ampl="sub", ylim=[0, 5])

# %% [markdown]
# ### Suprathreshold amplitudes

# %%
det_comp_param(recs, "Peak_amplitude", stim_ampl="supra", ylim=[0, 5])
